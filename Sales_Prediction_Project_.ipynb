# %% [markdown]
# # Task 4: Sales Prediction Project

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df=pd.read_csv('car_purchasing.csv')
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
# Checking null values
df.isnull().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
df.describe()
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
# Visualization step
# Detecting outlier using Normal Distribution
sns.distplot(df["gender"])
plt.show()
sns.distplot(df["age"])
plt.show()
sns.distplot(df["credit card debt"])
plt.show()
sns.distplot(df["net worth"])
plt.show()
sns.distplot(df["car purchase amount"])
plt.show()
# Out:
# C:\Users\chopa\AppData\Local\Temp\ipykernel_18980\1732479872.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["gender"])
# C:\Users\chopa\AppData\Local\Temp\ipykernel_18980\1732479872.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["age"])
# ...

# %%
# Feature Scaling(Standard Scaling)
from sklearn.preprocessing import StandardScaler

# %%
# Model training and testing
ss=StandardScaler()
ss.fit(df[["age"]])
# Out:
# StandardScaler()

# %%
df["age_ss"]=pd.DataFrame(ss.transform(df[["age"]]))
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount    age_ss
# 0  238961.2505          35321.45877 -0.550749
# ...

# %%
# Model training and testing
ss.fit(df[["annual Salary"]])
# Out:
# StandardScaler()

# %%
df["annual Salary_ss"]=pd.DataFrame(ss.transform(df[["annual Salary"]]))
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount    age_ss  annual Salary_ss
# 0  238961.2505          35321.45877 -0.550749          0.058576
# ...

# %%
# Model training and testing
ss.fit(df[["credit card debt"]])
# Out:
# StandardScaler()

# %%
df["credit card debt_ss"]=pd.DataFrame(ss.transform(df[["credit card debt"]]))
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount    age_ss  annual Salary_ss  \
# 0  238961.2505          35321.45877 -0.550749          0.058576
# ...

# %%
# Model training and testing
ss.fit(df[["net worth"]])
# Out:
# StandardScaler()

# %%
df["net worth_ss"]=pd.DataFrame(ss.transform(df[["net worth"]]))
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount    age_ss  annual Salary_ss  \
# 0  238961.2505          35321.45877 -0.550749          0.058576
# ...

# %%
# Visualizing the Before and After state of each column after Feature Scaling
sns.distplot(df["age"])
plt.title("Before")
plt.show()
sns.distplot(df["age_ss"])
plt.title("After")
plt.show()
sns.distplot(df["annual Salary"])
plt.title("Before")
plt.show()
sns.distplot(df["annual Salary_ss"])
plt.title("After")
plt.show()
sns.distplot(df["credit card debt"])
plt.title("Before")
plt.show()
sns.distplot(df["credit card debt_ss"])
plt.title("After")
plt.show()
sns.distplot(df["net worth"])
plt.title("Before")
plt.show()
sns.distplot(df["net worth_ss"])
plt.title("After")
plt.show()
# Out:
# C:\Users\chopa\AppData\Local\Temp\ipykernel_18980\3912550916.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["age"])
# C:\Users\chopa\AppData\Local\Temp\ipykernel_18980\3912550916.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["age_ss"])
# ...

# %%
# 1. Drop irrelevant columns
df_model = df.drop(columns=['customer name', 'customer e-mail'])

# 2. Separate features and target
X = df_model.drop(columns=['car purchase amount'])
y = df_model['car purchase amount']

# 3. Encode 'country' with OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

column_transformer = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(drop='first'), ['country'])
    ],
    remainder='passthrough'
)

X_encoded = column_transformer.fit_transform(X)

# 4. Split the encoded data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42)

# 5. Train the model on encoded data
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# Testing the data
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 2.0862131079829123
# MSE: 6.154867527632186
# R² Score: 0.9999999429963191

# %%
# Testing the data
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("Random Forest R² Score:", r2_score(y_test, y_pred_rf))
# Out:
# Random Forest R² Score: 0.9486666618287154

# %%
# Visualizing the Predicted price to the Actual price
plt.scatter(y_test, y_pred, alpha=0.6)
plt.xlabel("Actual Purchase Amount")
plt.ylabel("Predicted Purchase Amount")
plt.title("Actual vs Predicted Sales")
plt.grid(True)
plt.show()

# %%
# Visualizing correlation analysis
# Selecting only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Now compute the correlation matrix
corr = numeric_df.corr()

# Visualize correlation with target
plt.figure(figsize=(10, 6))
sns.heatmap(corr[['car purchase amount']].sort_values(by='car purchase amount', ascending=False), 
            annot=True, cmap='coolwarm')
plt.title("Correlation with Car Purchase Amount")
plt.show()

# %%
# After one-hot encoding:
X_encoded = pd.get_dummies(X, drop_first=True)  # This has 219 columns now
X_scaled = ss.fit_transform(X_encoded)      # You used this for training

# Use these for correct feature importance
feature_importance = pd.Series(rf.feature_importances_, index=X_encoded.columns)
feature_importance = feature_importance.sort_values(ascending=False)

# Plot
plt.figure(figsize=(12, 8))
sns.barplot(x=feature_importance[:20], y=feature_importance.index[:20])  # top 20
plt.title("Top 20 Feature Importances from Random Forest")
plt.xlabel("Importance Score")
plt.show()

# %%
# Visualizing Customer Segmentation Analysis 
# Example: Use age and income to segment
sns.scatterplot(data=df, x='age', y='annual Salary', hue='car purchase amount', palette='coolwarm')
plt.title('Customer Segments by Age and Income')
plt.show()
